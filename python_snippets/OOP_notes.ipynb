# %% [markdown]
# # OOP Notes
# Class names are typically written in CamelCase, with the first letter of each word capitalized and no underscores. # This is a convention in Python to  distinguish class names from variable and function names, which are typically written in snake_case.

# %% [markdown]
# Methods in a class are defined using the def keyword, just like functions. __init__ is a special method called a constructor, which is called when an instance of the class is created. It initializes the attributes of the class.
#
#     ``` def __init__(self, name, age):): ```
#
# every method in a class takes at least one parameter, which is usually named self. This parameter refers to the instance of the class itself, allowing you  to access its attributes and methods. The self parameter is not explicitly passed when you call the method; Python automatically provides it.
#
# Any variable that is prefixed with self. is an instance variable, which means it is tied to a specific instance of the class. In this case, name and age are instance variables that store the name and age of the dog.
#
# Instance variables are also known as attributes or properties of the class.

# %%
class Dog:
    """A simple dog class."""  

    def __init__(self, name, age):
        """Initialize the dog with a name and age."""
        self.name = name
        self.age = age
    def sit(self):
        """Make the dog sit."""
        print(f"{self.name} is now sitting.")
    
    def roll_over(self):
        """Make the dog roll over."""
        print(f"{self.name} rolled over!")

# %%
# Let's create an instance of the Dog class and call its methods.
my_dog = Dog("Buddy", 3)
print(f"My dog's name is {my_dog.name} and he is {my_dog.age} years old.")
my_dog.roll_over()  # Output: Buddy rolled over!
# The instance variable name is accessed using self.name, and the instance
# variable age is accessed using self.age. This allows you to store and retrieve
# information specific to each instance of the class.
my_dog.sit()  # Output: Buddy is now sitting.
# Out:
# My dog's name is Buddy and he is 3 years old.
# Buddy rolled over!
# Buddy is now sitting.

# %% [markdown]
# Consider a class is a set of instructions to make an instance.  The Dog class is a set of instructions to tell the interpreter how to make a dog class.
#
# We access attributes or methods of an instance using dot_notation

# %%
my_dog.sit()
my_dog.name
# Out:
# Buddy is now sitting.
# 'Buddy'

# %%
your_dog = Dog("Rex", 5)
print(f"Your dog's name is {your_dog.name} and he is {your_dog.age} years old.")
your_dog.roll_over()  # Output: Rex rolled over!
print(f' My dog is {my_dog.name} and your dog is {your_dog.name}.')
# Out:
# Your dog's name is Rex and he is 5 years old.
# Rex rolled over!
#  My dog is Buddy and your dog is Rex.

# %%
# Made a module for the car class
# File: car.py
from car import Car


### Let's create an instance of the Car class and call its methods.

print('Initize the instance')
my_car = Car('audi', 'a4', 2020)
print(my_car.get_description())  # Output: 2020 Audi A4
my_car.read_odometer()  # Output: This car has 0 miles on it.

### Here we are setting the attribute thru the instance:
print('Setting the odomerter thru the instance')
my_car.odometer_reading = 23
my_car.read_odometer()  # Output: This car has 23 miles on it.

### Here we are setting the attribute thru incrementing the value
print('Incrementing the odometer reading')
my_car.increment_odometer(100)
my_car.read_odometer()  # Output: This car has 123 miles on it.


my_prius = Car('toyota', 'prius', 2019)
print(my_prius.get_description())  # Output: 2019 Toyota Prius
my_prius.read_odometer()  # Output: This car has 0 miles on it

my_prius.battery.describe_battery()  # Output: This car has a 75-kWh battery.
my_prius.battery.get_range()  # Output: This car can go approximately 240 miles on a full charge.
# Out:
# Initize the instance
# 2020 Audi A4
# This car has 0 miles on it.
# Setting the odomerter thru the instance
# This car has 23 miles on it.
# Incrementing the odometer reading
# This car has 123 miles on it.
# 2019 Toyota Prius
# This car has 0 miles on it.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 28
#      25 print(my_prius.get_description())  # Output: 2019 Toyota Prius
#      26 my_prius.read_odometer()  # Output: This car has 0 miles on it
# ---> 28 my_prius.battery.describe_battery()  # Output: This car has a 75-kWh battery.
#      29 my_prius.battery.get_range()  # Output: This car can go approximately 240 miles on a full charge.
#
# AttributeError: 'Car' object has no attribute 'battery'

# %% [markdown]
# Modify the attributes
# 1. Directly modify the attribute thru an instance
# 2. Modify the value thru a method:  note the def update_odometer method above
# 3. Increment an attribute

# %% [markdown]
# # Inheritance
# Initializing a child class __init__() - sometimes  we want to use the __it__ method from the parent class.  This allows us to use any of the attributes from the parent class and use them with the child.
#
# Below we will create a child class (electric car) from the original car object.

# %%
from car import ElectricCar, Battery, Car


# Let's create an instance of the ElectricCar class and call its methods.
# Let's create an instance of the ElectricCar class and call its methods.
my_electric_car = ElectricCar('nissan', 'leaf', 2022)
print(my_electric_car.get_description())  # Output: 2022 Nissan Leaf
my_electric_car.battery.describe_battery()  # Output: This car has a 75-kWh battery.
my_electric_car.battery.get_range()  # Output: This car can go approximately
# Out:
# 2022 Nissan Leaf
# This car has a 75-kWh battery.
# This car can go approximately 240 miles on a full charge.

# %% [markdown]
# Because this extend out and we can keep adding more and more attributes and methods, sometime we want to create an instance as an attribute.  Below I will create a battery instance that can be used with the elect

# %% [markdown]
# These are practice examples i did to reinforce the learning process.

# %%
# Sample creation of a few classes and instances

class Restaurant:
    """A simple restaurant class."""
    
    def __init__(self, name, cuisine_type):
        """Initialize the restaurant with a name and cuisine type."""
        self.name = name
        self.cuisine_type = cuisine_type
    
    def describe_restaurant(self):
        """Describe the restaurant."""
        print(f"{self.name} serves {self.cuisine_type} cuisine.")
    
    def open_restaurant(self):
        """Open the restaurant."""
        print(f"{self.name} is now open!")

# %%
my_restaurant = Restaurant("Pasta Palace", "Italian")
my_restaurant.describe_restaurant()  # Output: Pasta Palace serves Italian cuisine.
my_restaurant.open_restaurant()  # Output: Pasta Palace is now open!


new_restaurant = Restaurant("Sushi Spot", "Japanese")
new_restaurant.describe_restaurant()  # Output: Sushi Spot serves Japanese cuisine.
new_restaurant.open_restaurant()  # Output: Sushi Spot is now open!

favorite_restaurant = Restaurant("Taco Town", "Mexican")
favorite_restaurant.describe_restaurant()  # Output: Taco Town serves Mexican cuisine.
favorite_restaurant.open_restaurant()  # Output: Taco Town is now open!
# Out:
# Pasta Palace serves Italian cuisine.
# Pasta Palace is now open!
# Sushi Spot serves Japanese cuisine.
# Sushi Spot is now open!
# Taco Town serves Mexican cuisine.
# Taco Town is now open!
